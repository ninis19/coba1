# %% [markdown]
# <a href="https://colab.research.google.com/github/ninis19/coba1/blob/main/latihan_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings; warnings.simplefilter('ignore')
import scipy, itertools, pandas as pd, matplotlib.pyplot as plt, seaborn as sns, numpy as np
from scipy import stats
from sklearn.preprocessing import StandardScaler, MinMaxScaler
plt.style.use('bmh'); sns.set()

# %%
file_ = 'data/price.csv'
try: # Running Locally, yakinkan "file_" berada di folder "data"
    price = pd.read_csv(file_, low_memory = False, encoding='utf8')
except: # Running in Google Colab
    # !mkdir data
    # !wget -P data/ https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/price.csv
    price = pd.read_csv(file_, low_memory = False, encoding='utf8')
    
N, P = price.shape # Ukuran Data
print('baris = ', N, ', Kolom (jumlah variabel) = ', P)
print("Tipe Variabe df = ", type(price))
price
# Out:
# mkdir: cannot create directory ‘data’: File exists
# --2022-09-21 15:27:01--  https://raw.githubusercontent.com/taudata-indonesia/eLearning/master/data/price.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53592 (52K) [text/plain]
# Saving to: ‘data/price.csv’
#
# price.csv           100%[===================>]  52.34K  --.-KB/s    in 0.03s
#
# 2022-09-21 15:27:01 (1.88 MB/s) - ‘data/price.csv’ saved [53592/53592]
#
# baris =  936 , Kolom (jumlah variabel) =  10
# Tipe Variabe df =  <class 'pandas.core.frame.DataFrame'>
#      Observation  Dist_Taxi  Dist_Market  Dist_Hospital  Carpet  Builtup  \
# 0              1     9796.0       5250.0        10703.0  1659.0   1961.0
# 1              2     8294.0       8186.0        12694.0  1461.0   1752.0
# ...

# %%
N, P = price.shape
print('Jumlah baris: ', N, ', Jumlah kolom: ',P)
# Out:
# Jumlah baris:  936 , Jumlah kolom:  10
